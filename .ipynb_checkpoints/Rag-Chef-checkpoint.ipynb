# %%
import langchain_community
import os
from langchain_community.embeddings.spacy_embeddings import SpacyEmbeddings
from langchain.document_loaders import CSVLoader
from langchain_community.vectorstores import DeepLake
from langchain.chains import RetrievalQA
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain.prompts import ChatPromptTemplate
from langchain_text_splitters import CharacterTextSplitter
from langchain_nvidia_ai_endpoints import ChatNVIDIA

# %%
#pip install langchain-nvidia-ai-endpoints
# Out:
# Collecting langchain-nvidia-ai-endpoints
#   Downloading langchain_nvidia_ai_endpoints-0.3.9-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-nvidia-ai-endpoints) (3.11.9)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-nvidia-ai-endpoints) (0.3.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (1.18.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (1.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (0.2.10)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (3.10.14)
# Requirement already satisfied: requests<3,>=2 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (2.23.4)
# Requirement already satisfied: idna>=2.0 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (3.7)
# Requirement already satisfied: anyio in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (4.2.0)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (2.2.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\envs\notebook-6.5.7\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-nvidia-ai-endpoints) (1.3.0)
# Downloading langchain_nvidia_ai_endpoints-0.3.9-py3-none-any.whl (41 kB)
# Installing collected packages: langchain-nvidia-ai-endpoints
# Successfully installed langchain-nvidia-ai-endpoints-0.3.9
# Note: you may need to restart the kernel to use updated packages.

# %%
os.environ["NVIDIA_API_KEY"] = "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"

# %%
loader = CSVLoader(file_path='recipes_data.csv',encoding = 'utf-8',
    csv_args={
    'delimiter': ',',
    'quotechar': '"',
    'fieldnames': ['directions', 'NER', 'source','ingredients','link','site'],
})

# %%
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=5000, chunk_overlap=500)
docs = text_splitter.split_documents(documents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\envs\notebook-6.5.7\Lib\site-packages\langchain_community\document_loaders\csv_loader.py:134, in CSVLoader.lazy_load(self)
#     133 try:
# --> 134     with open(self.file_path, newline="", encoding=self.encoding) as csvfile:
#     135         yield from self.__read_file(csvfile)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'recipes_data.csv'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 documents = loader.load()
#       2 text_splitter = CharacterTextSplitter(chunk_size=5000, chunk_overlap=500)
#       3 docs = text_splitter.split_documents(documents)
#
# File ~\anaconda3\envs\notebook-6.5.7\Lib\site-packages\langchain_core\document_loaders\base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File ~\anaconda3\envs\notebook-6.5.7\Lib\site-packages\langchain_community\document_loaders\csv_loader.py:151, in CSVLoader.lazy_load(self)
#     149         raise RuntimeError(f"Error loading {self.file_path}") from e
#     150 except Exception as e:
# --> 151     raise RuntimeError(f"Error loading {self.file_path}") from e
#
# RuntimeError: Error loading recipes_data.csv

# %%
embeddings = SpacyEmbeddings(model_name="en_core_web_sm")

# %%
llm = ChatNVIDIA(model="nvidia/llama-3.1-nemotron-51b-instruct")

# %%
db = DeepLake(dataset_path="./my_deeplake/", embedding=embeddings, read_only = True)
# db.add_documents(docs)

# %%
system_prompt = (
    "You are an assistant that provides recipes based on available ingredients and desired cuisine. "
    "Use the following pieces of retrieved context to answer the question. If you don't know the answer, say that you don't know.\n\n"
    "{context}"
)

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{question}")
])

# %%
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=db.as_retriever(),
    chain_type_kwargs={"prompt": prompt},
    input_key="question"
)

# %%
def find_recipes(ingredients, cuisine):
    input_question = f"Find me a recipe using these ingredients: {ingredients} with cuisine type: {cuisine}."
    answer = qa.invoke({"question": input_question})
    return answer['result']

# %%
ingredients_input = "chicken, tomatoes, garlic"
cuisine_input = "Italian"
recipe_response = find_recipes(ingredients_input, cuisine_input)
print(recipe_response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 ingredients_input = "chicken, tomatoes, garlic"
#       2 cuisine_input = "Italian"
# ----> 3 recipe_response = find_recipes(ingredients_input, cuisine_input)
#       4 print(recipe_response)
#
# NameError: name 'find_recipes' is not defined
